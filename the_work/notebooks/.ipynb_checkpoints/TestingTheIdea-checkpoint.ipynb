# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from matplotlib import pylab
import scipy as sp
from scipy.sparse import csc_matrix, csr_matrix, load_npz, save_npz, issparse
from chord_scripts import plot_spectrogram

# %%
def plot_frequencies(data, title=None):
    if issparse(data):
        data = sp.absolute(data.toarray()[:,0])
    
    plt.figure(figsize=(15, 7.5))
    plt.plot(range(len(data)), data)
    plt.title = title
    plt.xlabel = 'Freqs'
    plt.ylabel = 'Values'
    plt.show()

# %% [markdown]
# # Задача: найти метрики для сравнения спектрограмм

# %% [markdown]
# Требование к метрике f (для типов аккордов):
# * Расстояние между аккордами с одинаковыми типами ~ 0, e.g. $$f(a, b)~=0, при \ a=b  $$
# * Расстояние между аккордами разных типов ~ $\inf$ $$f(a,b) ~= \inf, при \ a \neq b$$

# %% [markdown]
# ## Придумаем метрику на аккордах A:min, A:maj, N

# %%
Amins = [load_npz('chords/A_min/{}.npz'.format(idx)).tocsr() for idx in range(3)]

# %%
Amajs = [load_npz('chords/A_maj/{}.npz'.format(idx)).tocsr() for idx in range(3)]

# %%
Amins[0]
# Out:
# <1025x5129 sparse matrix of type '<type 'numpy.complex128'>'
# 	with 44997 stored elements in Compressed Sparse Row format>

# %%
sums = sum([Amins[0][:,i] for i in range(Amins[0].shape[1])])

# %%
plot_frequencies(sums)

# %%
plot_spectrogram(Amins[0].toarray())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-862cbff83363> in <module>()
# ----> 1 plot_spectrogram(Amins[0].toarray())
#
# /home/egor/Yandex.Disk/Science/ChordRecognition17/chord_scripts.pyc in plot_spectrogram(spectrogram)
#      10     #plt.pcolormesh(times, frequencies, spectogram)
#      11     plt.colorbar()
# ---> 12     plt.ylabel('Frequency')
#      13     plt.xlabel('Frames')
#      14     plt.show()
#
# TypeError: 'str' object is not callable

# %%
plt.figure(figsize=(15, 7.5))
plt.plot(range(len(sums.toarray()[:,0])), sums.toarray()[:,0])
plt.title('asd')
plt.xlabel = 'Freqs'
plt.ylabel = 'Values'
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-81-958002b1326e> in <module>()
#       1 plt.figure(figsize=(15, 7.5))
#       2 plt.plot(range(len(sums.toarray()[:,0])), sums.toarray()[:,0])
# ----> 3 plt.title('asd')
#       4 plt.xlabel = 'Freqs'
#       5 plt.ylabel = 'Values'
#
# TypeError: 'str' object is not callable

# %%
plt.figure(figsize=(15, 7.5))
plt.imshow(sp.absolute(Amajs[0].toarray()), origin="lower", cmap="jet",aspect="auto", interpolation="nearest")
#plt.pcolormesh(times, frequencies, spectogram)
plt.colorbar()
#plt.ylabel('Frequency [Hz]')
#plt.xlabel('Time [sec]')
plt.show()
