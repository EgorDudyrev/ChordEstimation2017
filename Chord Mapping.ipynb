# %%
#Create Dictionary for MIDI notes
MIDInote = {'A': 57, 'A#': 58, 'Bb': 58, 'B': 59, 'Cb': 59,'C': 60, 'C#': 61, 'Db': 61,
         'D': 62, 'D#': 63, 'Eb': 63, 'E': 64, 'E#': 65, 'F': 65, 'F#': 66, 'Gb': 66, 
         'G': 67, 'G#': 68, 'Ab': 68}
         
#Create dicitionary for chords in semitone intervals
chType = {'N': 0, 'maj' : [0, 4, 7], 'min' : [0, 3, 7], 'maj7' : [0, 4, 7, 11],
          'min7' : [0, 3, 7, 10], '7' : [0, 4, 7, 10], 'sus4' : [0, 5, 7], 
          'sus2' : [0, 2, 7], 'maj6' : [0, 4, 7, 9], '1' : [0], '5' : [0, 7],
          'maj11' : [0, 4, 7, 11, 14, 17], '11' : [0, 4, 7, 10, 14, 17],
          'min11' : [0, 3, 7, 10, 14, 17], 'maj13' : [0, 4, 7, 11, 14, 17, 21],
          '13' : [0, 4, 7, 10, 14, 17, 21], 'min13' : [0, 3, 7, 10, 14, 17, 21],
          'dim' : [0, 3, 6], 'aug' : [0, 4, 8], 'min6' : [0, 3, 7, 9],
          '9' : [0, 4, 7, 10, 14], 'maj9' : [0, 4, 7, 11, 14], 'min9' : [0, 3, 7, 10, 14],
          'hdim7' : [0, 3, 6, 10], '' : [0], 'minmaj7': [0, 3, 7, 11],
          'dim7' : [0, 3, 6, 9]}

#Intervalos a intervalos en semitonos
interval = {'1' : 0, '2' : 2, '3' : 4, '4' : 5, '5' : 7, '6' : 9, '7' : 11,
            '8' : 12, '9' : 14, '10' : 16, '11' : 17, '12' : 19, '13' : 21}

modifier = {'b' : -1, '#': 1}

# %%
def map_chords(chords, _type='MinMaj'):
    if type(chords)==str:
        chords = [chords]
    nchords = []
    for chord in chords:
        if len(chord) == 1:
            nchords.append('N')
            continue
        root,chord = chord.split(':')
        allowed_chords = {}
        if 'MinMaj' in _type:
            allowed_chords['maj']= chType['maj']
            allowed_chords['min']= chType['min']
        
        similar_chords = sorted([sim_ch for sim_ch in chType if chord.startswith(sim_ch)], key=lambda x: -len(x))
        if not similar_chords:
            nchords.append('Not found')
            continue 
         
        #print similar_chords
        notes = chType.get(similar_chords[0])
        if notes==0:
            nchords.append('N')
            continue
        #print 'notes',notes
        
        is_find = False
        for chName, chNotes in allowed_chords.items():
            if all([x in notes for x in chNotes]):
                nchords.append(root+':'+chName)
                is_find = True
                break
        if not is_find:
            nchords.append('N')
    return nchords

# %%
map_chords("A:7(#9)")
# Out:
# ['A:maj']

# %% [markdown]
# # Смотрим какие аккорды имеются

# %%
chords_set = set()
with open('McGill-Billboard Parsed/all_dirs.txt') as f:
    for d in f.readlines():
        d = d.strip()
        if d=='all_dirs.txt':
            continue
        with open('McGill-Billboard Parsed/'+d+'/full.lab') as f1:
            for line in f1.readlines():
                try:
                    chords_set.add((line.split()[2]))
                except IndexError:
                    pass
chords_set = list(chords_set)

# %%
chords_set
# Out:
# ['Eb:aug',
#  'Fb:5(b7)',
#  'A:sus4(b7,9)',
#  'Db:sus4(9)',
#  'C#:7/4',
#  'D:9',
#  'F:min(9)',
#  'Gb:maj6(b7)',
#  'G:5(b7)',
#  'G:maj/b3',
#  'D:maj(#9)',
#  'Eb:sus4(b7,9)',
#  'G:maj/b7',
#  'G:9/5',
#  'G:maj13',
#  'D:min9/5',
#  'Eb:maj6(9)',
#  'F#:maj(9)',
#  'Gb:maj6(9)',
#  'A:5(b7)/b7',
#  'C:maj(#11)',
#  'Bb:min/b7',
#  'Db:7/b7',
#  'Ab:7(b13)',
#  'Eb:maj(#11)',
#  'Cb:7',
#  'C#:min/3',
#  'Ab:maj9',
#  'Ab:maj6',
#  'Ab:maj7',
#  'G:min7/b7',
#  'Cb:9',
#  'B:7(b9,b13)',
#  'D#:maj/b6',
#  'G:min7/5',
#  'Gb:maj9',
#  'Ab:maj/3',
#  'Gb:maj6',
#  'Gb:maj7',
#  'F:1/1',
#  'Ab:7/b7',
#  'Ab:hdim7',
#  'E:sus4',
#  'Ab:maj/7',
#  'Db:min',
#  'F:9/5',
#  'E:sus2(b7)',
#  'B:7/6',
#  'E:sus2',
#  'Ab:maj/5',
#  'G:maj9',
#  'F:maj6(9)',
#  'E:aug(b7)',
#  'C:sus4/4',
#  'E:min(9)/7',
#  'G:maj7',
#  'G:maj6',
#  'D:min7/b7',
#  'F:hdim7/b7',
#  'C:sus2/2',
#  'C:sus2/5',
#  'G:7(b9)',
#  'Eb:min11',
#  'Cb:maj7',
#  'F:11',
#  'G:dim',
#  'C:min7',
#  'C:min6',
#  'F:min7(11)',
#  'C:min9',
#  'F#:sus4',
#  'Bb:sus4',
#  'Eb:min7',
#  'C#:min',
#  'A:sus2',
#  'A:13',
#  'Bb:dim',
#  'A:11',
#  'G:hdim7/b5',
#  'A:sus4',
#  'F:sus4(b7)/b7',
#  'Ab:maj6(7)',
#  'C:5/5',
#  'F:sus4(b7)',
#  'A:min7/b3',
#  'E:min/2',
#  'A:maj6(9)',
#  'D:sus4',
#  'A:dim7',
#  'Db:(b7)',
#  'D:sus2',
#  'G:maj(11)',
#  'Bb:7(b9)',
#  'C:min/b7',
#  'A:hdim7',
#  'Eb:13',
#  'F:(3)',
#  'Eb:11',
#  'C:7(b9)',
#  'C:maj6(9)',
#  'F:min',
#  'D:maj7/2',
#  'D:sus2/2',
#  'Bb:sus4(9)',
#  'Ab:min(11)',
#  'C#:min7/4',
#  'G:maj(11)/4',
#  'Gb:1/1',
#  'A:7(b9)/b7',
#  'Gb:min7',
#  'D:7/5',
#  'C:min/6',
#  'C:min/5',
#  'Bb:(3)',
#  'F#:maj6/6',
#  'C:11',
#  'Bb:7(b9,b13)',
#  'A:maj(11)/b7',
#  'C#:maj/b4',
#  'F#:7(b13)',
#  'F:7(#9)',
#  'D:hdim7',
#  'G:9/3',
#  'Eb:min(b13)',
#  'Eb:maj',
#  'A:min/b6',
#  'A:min/b7',
#  'A:min/b3',
#  'C:(3)/2',
#  'B:min/b7',
#  'Eb:min6(#11)',
#  'B:min/b3',
#  'F#:maj(11)',
#  'Ab:maj7/3',
#  'Db:7(#11)',
#  'E:7(b13)/3',
#  'F#:sus4(b7)',
#  'B:min',
#  'Bb:aug(b7)',
#  'Eb:7/3',
#  'Db:aug',
#  'B:7(b9)/3',
#  'E:min',
#  'C:7(b9)/3',
#  'Db:sus4',
#  'D:min11/5',
#  'Cb:1/1',
#  'A:maj(#9)',
#  'Ab:maj6/4',
#  'F#:min(b13)',
#  'C:maj7',
#  'C:maj6',
#  'C:maj9',
#  'F#:min7(11)',
#  'E:7/b3',
#  'G#:sus4(b7,9)',
#  'G:sus4(b7,9)',
#  'A:min11',
#  'F:min6(9)/5',
#  'D:1/1',
#  'A:maj/b7',
#  'C#:min/5',
#  'E:7(b9)',
#  'B:min/4',
#  'C:maj13',
#  'A:maj(9)/5',
#  'Eb:maj7(#5)',
#  'D:7(#11)',
#  'Ab:maj6/5',
#  'B:min/5',
#  'B:maj/b4',
#  'G:sus4/5',
#  'G:sus4/4',
#  'G:sus4/2',
#  'C#:min(b13)',
#  'Bb:min7/b7',
#  'B:maj/b6',
#  'G:maj/#4',
#  'C#:7(#9)',
#  'D:7/b7',
#  'B:min11/b7',
#  'A#:dim7',
#  'D:maj7(#11)',
#  'Ab:7(#9)',
#  'E:dim/b5',
#  'C:maj(9)/3',
#  'G#:1/1',
#  'D:maj9(13)',
#  'E:(3)/3',
#  'Db:maj(11)',
#  'D:min(11)',
#  'C#:sus4(b7)',
#  'F:(b5,11)',
#  'Db:maj/b7',
#  'B:min7/4',
#  'Ab:(b7)',
#  'D:min/b3',
#  'G:7/b7',
#  'D:min/b7',
#  'C#:sus2(b7)',
#  'G:7/b3',
#  'F:sus2',
#  'G:sus4(b7)/4',
#  'Eb:sus4(b7)',
#  'F:sus4',
#  'G:min9',
#  'G:min/5',
#  'G:min/4',
#  'A:7(#11)',
#  'D:maj6(7)',
#  'B:min7/5',
#  'G:min7',
#  'G:min6',
#  'F:min(b13)',
#  'Gb:maj/5',
#  'Gb:maj/2',
#  'Gb:maj/3',
#  'E:min7/b3',
#  'B:min(9)',
#  'C:maj9(#11)',
#  'B:7(#11)',
#  'F#:min11',
#  'D:5/5',
#  'G:min/b3',
#  'B:aug(b7)/3',
#  'F:7(b9)',
#  'Bb:maj/b7',
#  'F#:min7/b7',
#  'F#:maj',
#  'Ab:min(b13)',
#  'B:dim(b13)',
#  'D:(#5)',
#  'A#:dim',
#  'C:sus4(9)',
#  'C:dim',
#  'A:hdim7/b5',
#  'B:sus2(b7)',
#  'B:13',
#  'Bb:maj9',
#  'B:11',
#  'B:7',
#  'Ab:maj6(9)',
#  'B:5',
#  'C#:hdim7',
#  'B:maj/2',
#  'C:maj6(7)',
#  'B:9',
#  'E:maj6(9)',
#  'C:min/b3',
#  'C:maj/7',
#  'C:maj/6',
#  'C:maj/5',
#  'C:maj/4',
#  'C:maj/3',
#  'C:maj/2',
#  'C:maj(11)',
#  'B:hdim7',
#  'C:9',
#  'D:hdim7/b3',
#  'C:7',
#  'C:5',
#  'C#:9',
#  'Eb:min/b3',
#  'E:maj/b7',
#  'Bb:min11/b7',
#  'Eb:min/b7',
#  'G:9',
#  'G:7',
#  'G:5',
#  'C#:5',
#  'C#:7',
#  'C:sus2',
#  'D#:sus4(b7)',
#  'C:sus4',
#  'F:aug(9)',
#  'Eb:sus4(b7,9)/5',
#  'D:11',
#  'Db:hdim7',
#  'B:7(b13)',
#  'F:sus4/5',
#  'A:maj7(#11)',
#  'A:5/4',
#  'Eb:7(b9)/3',
#  'Gb:min/3',
#  'C:min6/b3',
#  'Fb:maj',
#  'F:hdim7',
#  'F#:11',
#  'F:9/3',
#  'F:minmaj7',
#  'F#:(b5,b7,3)',
#  'G#:sus4(b7)',
#  'C:7(11)',
#  'F:min/5',
#  'F:min/4',
#  'Ab:maj/2',
#  'G:min7/4',
#  'Ab:maj/6',
#  'Bb:maj13',
#  'Ab:maj/4',
#  'Gb:maj',
#  'Bb:min/2',
#  'C#:5(b7)',
#  'Bb:min',
#  'Bb:min/5',
#  'B:maj6(b9)',
#  'Bb:sus4(b7)/b7',
#  'C#:(b3,b7,11,9)',
#  'Eb:min6',
#  'E:(b3,b7,11,9)',
#  'Ab:maj(9)/6',
#  'Ab:maj(9)/3',
#  'D:min',
#  'Bb:5/2',
#  'B:min(11)/b7',
#  'F:sus2/3',
#  'B:maj/b7',
#  'Eb:min9',
#  'Ab:7(b9)',
#  'B:maj6/3',
#  'G:7/b5',
#  'F:maj',
#  'F#:maj(9)/3',
#  'Fb:(3,7)',
#  'A:9/3',
#  'A:sus2(b7)',
#  'Eb:maj6',
#  'Eb:maj7',
#  'Ab:sus4/5',
#  'Eb:maj9',
#  'G#:sus4',
#  'D:7(#9)',
#  'E:maj/b5',
#  'G:minmaj7',
#  'Db:maj(9)/5',
#  'C:sus4/7',
#  'A:min',
#  'E:aug(7)',
#  'C:minmaj7',
#  'Eb:min7/b7',
#  'D:maj7',
#  'Bb:maj6/b7',
#  'Eb:min7(11)',
#  'C:1/1',
#  'Ab:dim',
#  'C:9(#11)',
#  'Bb:9/3',
#  'Gb:maj(9)',
#  'D:min13',
#  'E:maj/3',
#  'D:min11',
#  'E:maj/5',
#  'E:maj/4',
#  'E:maj/7',
#  'G#:min7(11)',
#  'Db:maj/5',
#  'Cb:7(#11)',
#  'Db:maj/7',
#  'Eb:sus4',
#  'Eb:sus2',
#  'Db:maj/3',
#  'Db:maj/2',
#  'C:(b5,b7,3)',
#  'Bb:hdim7',
#  'A:min(9)/6',
#  'Eb:min9/b7',
#  'E:hdim7',
#  'C:sus2(#11)',
#  'Eb:sus4(b7,9,#11)',
#  'C#:sus4(b7,9)',
#  'Bb:1/1',
#  'Db:maj/4',
#  'Eb:dim',
#  'F:maj(9)/5',
#  'E:min7(11)',
#  'Db:maj13',
#  'Db:dim/b3',
#  'A:7',
#  'Bb:7/5',
#  'E:sus4(b7)',
#  'Bb:7/3',
#  'D:min/4',
#  'D:min/5',
#  'D:min/6',
#  'D:min/2',
#  'E:sus4(9)',
#  'C:min',
#  'C#:min11',
#  'F#:min',
#  'Bb:minmaj7',
#  'Db:maj9(#11)',
#  'A:9/5',
#  'E:sus4(b7,9,13)',
#  'A:(11,9)',
#  'Bb:minmaj7/7',
#  'A:7(b9,b13)',
#  'Eb:min(9)',
#  'C:9(13,#11)',
#  'F:min6/b3',
#  'Eb:min13',
#  'Bb:maj6(9)',
#  'Ab:min/b3',
#  'Gb:13',
#  'Eb:min7/4',
#  'C:hdim7',
#  'B:sus4(b7)',
#  'F#:aug(b7)',
#  'Bb:7',
#  'Eb:min6/5',
#  'Bb:5',
#  'Ab:maj/b7',
#  'E:hdim7/b7',
#  'F#:min6',
#  'F#:min7',
#  'Ab:maj(9)',
#  'Bb:9',
#  'Eb:7',
#  'B:7(#9)',
#  'Eb:5',
#  'Eb:9',
#  'A:min7/6',
#  'A:min7/5',
#  'A:min7/4',
#  'B:sus4/b7',
#  'Db:5(b7)',
#  'C:7/b7',
#  'E:maj(#9)',
#  'D:dim',
#  'Eb:min7(b13)',
#  'B:maj',
#  'Eb:maj7(#11)',
#  'C:(11)',
#  'E:5(b7)',
#  'Eb:maj/6',
#  'Eb:maj/7',
#  'Eb:maj/4',
#  'Eb:maj/5',
#  'Eb:maj/2',
#  'Eb:maj/3',
#  'A:maj',
#  'A:dim/b3',
#  'B:sus4(b7,9)',
#  'E:(b3,b7)/b7',
#  'D:sus4/b7',
#  'E:min(9)',
#  'Eb:1/1',
#  'Db:maj6(9)/5',
#  'Ab:min9',
#  'F:min/b7',
#  'F#:9',
#  'F#:7',
#  'A:7(b9)/5',
#  'F#:5',
#  'C:min(9)/5',
#  'Ab:min6',
#  'Ab:min7',
#  'A:7(b9)/3',
#  'Bb:maj/7',
#  'Bb:maj/6',
#  'Bb:maj/5',
#  'Bb:maj/3',
#  'Bb:maj/2',
#  'A:1/1',
#  'Gb:maj13',
#  'A:dim/b5',
#  'F#:min/4',
#  'E:dim',
#  'Db:5',
#  'Db:7',
#  'A:(b7)/b7',
#  'G:maj',
#  'Db:9',
#  'G#:min/7',
#  'Eb:min',
#  'D:maj6(9)/5',
#  'E:7/3',
#  'Ab:maj7/2',
#  'E:7/5',
#  'B:maj7(b7)/3',
#  'D:maj/b7',
#  'Cb:min6',
#  'E:min/b7',
#  'D:maj/b3',
#  'Ab:maj6/2',
#  'Eb:7/5',
#  'A:7/4',
#  'A:7/5',
#  'A:7/6',
#  'D:7/b4',
#  'Bb:sus2',
#  'A:7/2',
#  'A:7/3',
#  'G#:min/bb7',
#  'B:sus4',
#  'Db:minmaj7/5',
#  'Ab:7/5',
#  'Db:min(9)',
#  'Fb:maj7',
#  'Ab:13',
#  'X',
#  'Ab:11',
#  'D:maj/2',
#  'F#:sus4/b7',
#  'E:(b5,b7,3)/b5',
#  'B:dim/b7',
#  'F:maj/b7',
#  'F#:sus4(b13,b7)',
#  'B:dim/b3',
#  'G:(b5,b7,3)',
#  'F:dim/#4',
#  'Cb:maj/2',
#  'A:(13)/6',
#  'A:5/6',
#  'Cb:maj/5',
#  'E:7(#9)',
#  'G:aug',
#  'Ab:maj6(b7)',
#  'Eb:maj7(#11)/3',
#  'E:maj(9)/3',
#  'G#:7',
#  'E:min6/2',
#  'A:5(b7)/2',
#  'A:5(b7)/3',
#  'Db:sus2',
#  'E:maj(11)',
#  'Gb:min',
#  'E:min7/5',
#  'A:sus4(b7,9,13)',
#  'D#:min7',
#  'F:maj/2',
#  'F:maj/3',
#  'Ab:min/5',
#  'F:maj/6',
#  'F:maj/7',
#  'F:maj/4',
#  'F:maj/5',
#  'C#:dim',
#  'F:maj(9)',
#  'Eb:(b5,b7,3)',
#  'Cb:maj7(#11)',
#  'Ab:maj',
#  'A:maj6/5',
#  'F:min9/4',
#  'C#:7(b9)/3',
#  'A:7(#9)',
#  'D:maj(b9)',
#  'C:maj/b7',
#  'Ab:sus2(b7)',
#  'A:(11)',
#  'Bb:maj',
#  'B:7(b9)/b2',
#  'F#:min/5',
#  'G#:7(b9)',
#  'D:sus4(b7)/5',
#  'Cb:maj',
#  'Gb:maj/b7',
#  'F#:7/b7',
#  'Cb:maj(9)',
#  'G#:min',
#  'D:maj/3',
#  'D:maj/4',
#  'D:maj/5',
#  'D:maj/6',
#  'D:maj/7',
#  'D:minmaj7',
#  'Eb:maj(9,#11)',
#  'C#:min11/b3',
#  'E:7/b7',
#  'E:9/3',
#  'G:sus4(b7,9,13)',
#  'F#:min/b3',
#  'D:maj',
#  'C:7(#9)',
#  'A:min7/b7',
#  'F:sus4(9)',
#  'A:9(13)',
#  'F#:hdim7/b3',
#  'D#:7',
#  'G:9(b13)',
#  'E:1/1',
#  'D:min(b13)',
#  'F#:hdim7/b5',
#  'F:maj6',
#  'F:maj7',
#  'A:aug',
#  'A:dim',
#  'C#:7(b9)',
#  'F#:7/b2',
#  'B:min(11)/7',
#  'G:maj6(7)',
#  'F:maj9',
#  'G#:maj/5',
#  'E:min9/4',
#  'B:5(b7)',
#  'Bb:min7',
#  'E:min9/2',
#  'Bb:min9',
#  'F:sus4(b7,9)/2',
#  'G#:min7',
#  'Db:maj9',
#  'Eb:maj7/5',
#  'F#:maj/2',
#  'F#:maj/3',
#  'Bb:sus4(b7)',
#  'F:maj13',
#  'F#:maj/6',
#  'Eb:maj6/5',
#  'F#:maj/5',
#  'G:maj6/b5',
#  'B:7(11)',
#  'D#:dim',
#  'D:min6',
#  'D:min7',
#  'D:min9',
#  'G#:min9',
#  'D:5(b7)',
#  'Gb:sus2',
#  'F:(b3)',
#  'F:sus2(b7)',
#  'A:min9(b13)',
#  'C:min7(11)',
#  'Ab:sus4(b7,9)',
#  'Gb:5',
#  'B:min7/b7',
#  'Gb:7',
#  'Bb:min7(11)',
#  'Bb:maj7/3',
#  'Bb:maj7/2',
#  'Bb:aug',
#  'Bb:maj7/7',
#  'F#:sus4(b7,9)',
#  'F:dim',
#  'C#:min7/b3',
#  'D:maj(9)/3',
#  'Bb:7(#9)',
#  'Bb:hdim7/b5',
#  'G:maj(9)/5',
#  'G:maj(9)/3',
#  'D:maj6/2',
#  'G:maj(9)',
#  'Gb:maj7/2',
#  'Eb:maj13',
#  'E:7(#11)',
#  'N',
#  'C:13',
#  'D:5',
#  'D:7',
#  'C:maj',
#  'Eb:7(#9)',
#  'A:min7(11)',
#  'F:maj(#11)',
#  'Cb:maj9',
#  'E:hdim7/b3',
#  'G#:dim',
#  'C:dim/7',
#  'G:hdim7',
#  'E:min/5',
#  'E:min/4',
#  'G:aug(b7)',
#  'F#:dim',
#  'F#:hdim7',
#  'Db:maj(9)',
#  'G:min11',
#  'C:sus4/5',
#  'D#:maj',
#  'A#:1/1',
#  'A:(#5)',
#  'A:maj/5',
#  'A:maj/4',
#  'A:maj/7',
#  'A:maj/6',
#  'B:min/6',
#  'A:minmaj7',
#  'A:maj/3',
#  'A:maj/2',
#  'G:sus2',
#  'Bb:sus4(9)/7',
#  'Ab:maj13',
#  'A:maj(9)',
#  'Ab:dim7/2',
#  'E:maj6',
#  'D:maj(9)',
#  'F:maj6/5',
#  'F:maj6/3',
#  'F:maj6/2',
#  'E:min11',
#  'A:5(b7)',
#  'F:maj7/7',
#  'F:maj7/4',
#  'Eb:hdim7/b7',
#  'Db:dim',
#  'F:maj7/3',
#  'G#:hdim7',
#  'Bb:maj7',
#  'Bb:maj6',
#  'B:maj6/5',
#  'E:sus4/2',
#  'F#:minmaj7',
#  'Eb:7(b13)',
#  'Bb:min6',
#  'D:min6(7)',
#  'B:min11',
#  'E:aug',
#  'Eb:maj(b9)',
#  'F#:7/5',
#  'F#:7/3',
#  'D:maj9',
#  'C:maj6/5',
#  'D:maj6',
#  'C:aug(b7)',
#  'C:maj6/3',
#  'F:5(b7)',
#  'Ab:maj7/7',
#  'G#:7(#9)',
#  'B:min9',
#  'Bb:7(#11)',
#  'B:min7',
#  'C#:dim7',
#  'Bb:11',
#  'Bb:13',
#  'F:min6',
#  'F:min7',
#  'Ab:9',
#  'Ab:7',
#  'Ab:5',
#  'F:min9',
#  'B:aug',
#  'Bb:maj(9)',
#  'E:11',
#  'B:7/b7',
#  'F:9',
#  'B:maj/bb6',
#  'F:7',
#  'F:5',
#  'A:maj7/7',
#  'G:min11/b3',
#  'A:maj7/5',
#  'A:maj7/2',
#  'F:maj6(9)/3',
#  'Bb:sus4(b7,9,13)',
#  'D:sus4(b7)/2',
#  'D#:dim/b2',
#  'D#:dim/b5',
#  'A:maj6/3',
#  'C#:min7',
#  'C#:min/b7',
#  'Db:min/5',
#  'D:7/3',
#  'C#:hdim7/4',
#  'C#:min9/b7',
#  'G:sus4',
#  'G:7/4',
#  'C#:min9',
#  'B:min11/5',
#  'G:min',
#  'Db:maj7',
#  'F#:min/b7',
#  'F#:min9',
#  'E:maj7/5',
#  'B:min7/b3',
#  'Db:maj6',
#  'Eb:maj/b7',
#  'Bb:maj6(7,#11)',
#  'E:min(b13)',
#  'F#:min/b8',
#  'C:aug',
#  'G:11',
#  'B:7/5',
#  'G:13',
#  'B:7/3',
#  'B:maj6(b7)',
#  'B:min(11,9)',
#  'D:7(b9)',
#  'Db:min9',
#  'C#:min(11)',
#  'C:min11',
#  'G:min7/2',
#  'A:min(9)',
#  'B:1/1',
#  'D:min(9)',
#  'Ab:sus2',
#  'G:maj7/3',
#  'G:maj7/2',
#  'G:maj7/5',
#  'Db:maj6(9)',
#  'Ab:sus4',
#  'D:min9/b7',
#  'G:maj6/3',
#  'F#:1/1',
#  'D:maj13',
#  'F:7(#11)',
#  'F:13',
#  'Db:maj',
#  'Ab:min7/5',
#  'D:7(b9,#11)',
#  'G:min7(11)',
#  'D:sus2(b7)',
#  'C:min(9)',
#  'Eb:maj6(7)',
#  'D#:min',
#  'G:sus4(9)',
#  'E:maj6/6',
#  'A:maj9/3',
#  'E:min9',
#  'E:min7',
#  'G:maj/2',
#  'C:sus4(b7,9)',
#  'G:maj/7',
#  'G:maj/6',
#  'G:maj/5',
#  'G:maj/4',
#  'Db:1/1',
#  'Ab:min7/4',
#  'A:sus4(9)',
#  'Db:11',
#  'D:sus4(b7,9)',
#  'D:(11)',
#  'G:dim7',
#  'C:5(b7)',
#  'F#:dim7',
#  'C:sus4(b7,9,13)',
#  'A:maj9',
#  'A:maj7',
#  'A:maj6',
#  'C#:maj',
#  'Gb:dim',
#  'E:minmaj7/5',
#  'B:5/5',
#  'Db:sus4(b7,9)',
#  'G#:min(11)',
#  'F#:maj/b3',
#  'Gb:maj(9)/2',
#  'F:aug',
#  'B:maj9',
#  'B:sus4(b7)/4',
#  'A:7/b7',
#  'C#:5(b13)',
#  'D:maj6/3',
#  'C:7(b9)/b2',
#  'B:maj6',
#  'B:maj7',
#  'C:sus4(b7)',
#  'A:sus4(b7)',
#  'A:min(11)',
#  'G:sus4(b7)',
#  'D:maj7/3',
#  'C:maj9/3',
#  'D:maj7/5',
#  'E:maj/2',
#  'G:7(#9)',
#  'Bb:5(b7)/5',
#  'A:min/5',
#  'A:min/4',
#  'A:min/6',
#  'F:9(#11)',
#  'Db:maj6/5',
#  'F:min11',
#  'Db:maj7/7',
#  'Eb:min/5',
#  'Db:7/3',
#  'Db:7/4',
#  'Db:7/5',
#  'B:7(b9)',
#  'Eb:minmaj7',
#  'E:min(11,9)',
#  'B:min(11)',
#  'B:maj/6',
#  'B:maj/7',
#  'B:maj/4',
#  'B:maj/5',
#  'Ab:5/5',
#  'B:maj/3',
#  'Bb:maj6/5',
#  'Gb:maj9(#11)',
#  'Ab:7(b9,b13)',
#  'G:maj6(9)',
#  'Ab:min11',
#  'D:min6/5',
#  'B:dim',
#  'G#:maj',
#  'D:min6/2',
#  'D:min7/4',
#  'D:min7/5',
#  'C:5(13)',
#  'C:maj(9)',
#  'B:maj(9)',
#  'G:maj/3',
#  'Ab:1/1',
#  'E:min6',
#  'C:min6/2',
#  'C:min7/b3',
#  'Eb:7/b7',
#  'B:aug/5',
#  'D:maj6(b7,11)',
#  'E:maj',
#  'A:9',
#  'F:min/b3',
#  'C:aug(b7,9)',
#  'F#:min/7',
#  'Bb:(b5,b7,3)',
#  'E:min/b3',
#  'A:5',
#  'A:7(b9)',
#  'Db:min7',
#  'A:min9',
#  'Ab:7/4',
#  'Ab:7/3',
#  'E:9',
#  'Ab:5/b7',
#  'E:5',
#  'E:7',
#  'A:min7',
#  'A:min6',
#  'Ab:sus4(b7)',
#  'Ab:min(9)',
#  'B:min7/b2',
#  'A:min(9)/b7',
#  'F:min7/4',
#  'A:maj(9)/3',
#  'A:(b5,b7,3)',
#  'Ab:min',
#  'F:min7/b3',
#  'F:sus4(b7,9)',
#  'Bb:sus4(b7)/4',
#  'Gb:7/5',
#  'F:maj9/4',
#  'E:sus4(b7,9)',
#  'G:7(b13)',
#  'E:maj9',
#  'G:maj7(#9)',
#  'E:7(b9)/4',
#  'F:min6/5',
#  'F:min7/2',
#  'E:maj7',
#  'C:maj/#4',
#  'E:dim7',
#  'F:min7/5',
#  'Bb:maj(9)/3',
#  'G:5/4',
#  'G:5/5',
#  'A:maj9(#11)',
#  'Gb:maj(11)',
#  'Bb:min11',
#  'Eb:maj(9)',
#  'D:sus4(b7)',
#  'B:min(11)/4',
#  'G:7/6',
#  'F#:7/6',
#  'G:7/5',
#  'G:7/3',
#  'Db:sus4(b7)',
#  'F:7/5',
#  'E:min9/b3',
#  'C#:min(9)',
#  'D:min7/b3',
#  'C:7/3',
#  'D:maj6(9)',
#  'Eb:7(b13,#9)',
#  'C:7/6',
#  'F:7/b7',
#  'C:7/5',
#  'Bb:sus4(b7,9)',
#  'G:1/1',
#  'A:sus4/5',
#  'F:5/6',
#  'Gb:(b7)',
#  'F:7/3',
#  'F:7/2',
#  'A#:maj',
#  'Eb:maj9(13,#11)',
#  'G#:maj/b2',
#  'C#:dim7/b3',
#  'F#:maj6',
#  'Gb:maj6/5',
#  'A:(b5,b7,3)/b5',
#  'C#:1/1']

# %%
chord_types = list(set([c.split(':')[1] if len(c)>1 else 'N' for c in chords_set]))

# %%
print len(chord_types)
print chord_types
# Out:
# 229
# ['maj6(b7)', '7/b2', '7/b3', '7/b4', '7/b5', '9(b13)', '7/b7', 'maj9(#11)', 'maj/b2', '7(b9)/5', 'sus2(#11)', '7(b9)/4', 'dim7/b3', 'maj/bb6', '(b3)', 'min7(11)', 'aug/5', '7(b9)/b2', '5/b7', 'aug', '7(b9)/b7', 'maj(11)', 'sus4(b7)/2', 'sus4(b7)/4', 'sus4(b7)/5', 'min/b7', 'min/b6', 'min/b3', 'dim/b3', 'min/4', 'min/5', 'min/6', 'min/7', 'hdim7', 'min/2', 'min/3', 'maj(9)/3', 'maj(9)/2', 'maj(b9)', 'dim/b5', 'min6(9)/5', 'dim/b7', '7(b9)/3', '5/6', 'dim', 'maj(9)/5', 'min(b13)', 'aug(9)', 'aug(b7)/3', 'maj6(7)', 'maj/b3', 'maj(11)/b7', 'maj/b7', 'maj/b6', 'maj/b5', 'maj/b4', 'maj9(13)', 'dim(b13)', '(b3,b7,11,9)', '(b7)/b7', '(#5)', 'maj/2', 'maj/3', 'maj/4', 'maj/5', 'maj/6', 'maj/7', 'sus2/2', 'sus2/3', 'sus2/5', '7(b9)', 'min6/5', 'sus4/b7', 'min6/2', 'maj(9,#11)', 'min9(b13)', 'min6(7)', 'min(11)/7', 'min(11)/4', 'sus2(b7)', 'maj6(b9)', 'min(9)', '7', 'min6/b3', 'min7/6', 'maj7/2', 'maj7/3', 'maj7/4', 'maj7/5', 'maj7/7', 'min7/4', 'min7/5', 'maj6/3', 'maj6/2', 'maj6/5', 'maj6/4', 'min7/2', 'maj6/6', 'dim/b2', 'min(11)/b7', 'sus4(9)', 'dim/#4', '7(b13,#9)', 'min13', '9(13,#11)', 'min11', 'maj(9)', 'maj7(b7)/3', 'dim/7', 'sus4(9)/7', '(b5,11)', 'N', '(3)/3', '9/5', '9(#11)', '9/3', 'maj6(9)/5', '(11,9)', '(b7)', 'min7(b13)', 'min9/4', '5(b7)/b7', 'minmaj7', 'sus4(b7,9,#11)', 'min/bb7', '(b5,b7,3)/b5', 'maj7(#11)/3', '(11)', 'min11/b7', 'sus4(b7,9)/2', 'min11/b3', 'maj6/b5', 'maj7(#9)', 'maj6/b7', 'maj(#11)', 'hdim7/b3', '5(b7)/3', '5(b7)/2', '5(b7)/5', 'hdim7/b7', 'hdim7/b5', 'maj9(13,#11)', 'min(11)', '9(13)', 'minmaj7/5', '7(11)', 'maj9/3', 'min6(#11)', '1/1', '5(b7)', 'sus4(b13,b7)', '(b5,b7,3)', 'maj9/4', 'min9/b3', 'aug(b7)', '(3,7)', 'maj13', '11', '5/2', '13', '(13)/6', 'maj(9)/6', '5/5', '5/4', 'minmaj7/7', 'sus4(b7)/b7', 'maj/#4', '5(b13)', '7(#9)', 'min(11,9)', '7(b9,b13)', 'min/b8', '7(#11)', 'hdim7/4', 'sus4(b7,9)', 'min9/5', 'min9/2', 'aug(7)', '(3)', '7(b13)/3', 'maj7(#11)', 'dim7', 'maj(11)/4', 'dim7/2', 'min11/5', 'min', 'sus4(b7)', 'maj6(9)/3', '5', 'maj9', '9', 'maj6(7,#11)', 'maj6', 'maj7', 'maj(#9)', '5(13)', 'maj7(#5)', 'maj6(9)', 'aug(b7,9)', 'min9/b7', '7(b9,#11)', 'min9', '(3)/2', 'sus2', 'sus4', 'min(9)/7', 'min(9)/6', 'min(9)/5', 'maj', 'sus4(b7,9)/5', 'min6', 'min7', 'sus4/2', 'sus4/7', 'sus4/4', 'sus4/5', '7/5', '7/4', '7/6', '(b3,b7)/b7', '7/3', '7/2', 'min(9)/b7', '7(b13)', 'sus4(b7,9,13)', 'min7/b7', 'maj6(b7,11)', 'min7/b3', 'min7/b2']

# %%
chords_set[498:501]
# Out:
# ['Ab:13', 'X', 'Ab:11']

# %%
len(chord_types), len(chords_set)
# Out:
# (229, 976)

# %%
map_chords(every_A_chord)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-61-7d9f8675b3c6> in <module>()
# ----> 1 map_chords(every_A_chord)
#
# <ipython-input-57-f92eed1f0262> in map_chords(chords, _type)
#      44             if type(chNotes)==int:
#      45                 print chName, chNotes
# ---> 46             if all([x in notes for x in chNotes]):
#      47                 nchords.append(chName)
#      48                 is_find = True
#
# TypeError: argument of type 'int' is not iterable

# %%
every_A_chord = map(lambda x: 'A:'+x, chord_types)
print sum(map(lambda x: x!='Not found', map_chords(every_A_chord))), len(every_A_chord)
zip(sorted(chord_types), map_chords(sorted(every_A_chord)))
# Out:
# 229 229
# [('(#5)', 'N'),
#  ('(11)', 'N'),
#  ('(11,9)', 'N'),
#  ('(13)/6', 'N'),
#  ('(3)', 'N'),
#  ('(3)/2', 'N'),
#  ('(3)/3', 'N'),
#  ('(3,7)', 'N'),
#  ('(b3)', 'N'),
#  ('(b3,b7)/b7', 'N'),
#  ('(b3,b7,11,9)', 'N'),
#  ('(b5,11)', 'N'),
#  ('(b5,b7,3)', 'N'),
#  ('(b5,b7,3)/b5', 'N'),
#  ('(b7)', 'N'),
#  ('(b7)/b7', 'N'),
#  ('1/1', 'N'),
#  ('11', 'maj'),
#  ('13', 'maj'),
#  ('5', 'N'),
#  ('5(13)', 'N'),
#  ('5(b13)', 'N'),
#  ('5(b7)', 'N'),
#  ('5(b7)/2', 'N'),
#  ('5(b7)/3', 'N'),
#  ('5(b7)/5', 'N'),
#  ('5(b7)/b7', 'N'),
#  ('5/2', 'N'),
#  ('5/4', 'N'),
#  ('5/5', 'N'),
#  ('5/6', 'N'),
#  ('5/b7', 'N'),
#  ('7', 'maj'),
#  ('7(#11)', 'maj'),
#  ('7(#9)', 'maj'),
#  ('7(11)', 'maj'),
#  ('7(b13)', 'maj'),
#  ('7(b13)/3', 'maj'),
#  ('7(b13,#9)', 'maj'),
#  ('7(b9)', 'maj'),
#  ('7(b9)/3', 'maj'),
#  ('7(b9)/4', 'maj'),
#  ('7(b9)/5', 'maj'),
#  ('7(b9)/b2', 'maj'),
#  ('7(b9)/b7', 'maj'),
#  ('7(b9,#11)', 'maj'),
#  ('7(b9,b13)', 'maj'),
#  ('7/2', 'maj'),
#  ('7/3', 'maj'),
#  ('7/4', 'maj'),
#  ('7/5', 'maj'),
#  ('7/6', 'maj'),
#  ('7/b2', 'maj'),
#  ('7/b3', 'maj'),
#  ('7/b4', 'maj'),
#  ('7/b5', 'maj'),
#  ('7/b7', 'maj'),
#  ('9', 'maj'),
#  ('9(#11)', 'maj'),
#  ('9(13)', 'maj'),
#  ('9(13,#11)', 'maj'),
#  ('9(b13)', 'maj'),
#  ('9/3', 'maj'),
#  ('9/5', 'maj'),
#  ('N', 'N'),
#  ('aug', 'N'),
#  ('aug(7)', 'N'),
#  ('aug(9)', 'N'),
#  ('aug(b7)', 'N'),
#  ('aug(b7)/3', 'N'),
#  ('aug(b7,9)', 'N'),
#  ('aug/5', 'N'),
#  ('dim', 'N'),
#  ('dim(b13)', 'N'),
#  ('dim/#4', 'N'),
#  ('dim/7', 'N'),
#  ('dim/b2', 'N'),
#  ('dim/b3', 'N'),
#  ('dim/b5', 'N'),
#  ('dim/b7', 'N'),
#  ('dim7', 'N'),
#  ('dim7/2', 'N'),
#  ('dim7/b3', 'N'),
#  ('hdim7', 'N'),
#  ('hdim7/4', 'N'),
#  ('hdim7/b3', 'N'),
#  ('hdim7/b5', 'N'),
#  ('hdim7/b7', 'N'),
#  ('maj', 'maj'),
#  ('maj(#11)', 'maj'),
#  ('maj(#9)', 'maj'),
#  ('maj(11)', 'maj'),
#  ('maj(11)/4', 'maj'),
#  ('maj(11)/b7', 'maj'),
#  ('maj(9)', 'maj'),
#  ('maj(9)/2', 'maj'),
#  ('maj(9)/3', 'maj'),
#  ('maj(9)/5', 'maj'),
#  ('maj(9)/6', 'maj'),
#  ('maj(9,#11)', 'maj'),
#  ('maj(b9)', 'maj'),
#  ('maj/#4', 'maj'),
#  ('maj/2', 'maj'),
#  ('maj/3', 'maj'),
#  ('maj/4', 'maj'),
#  ('maj/5', 'maj'),
#  ('maj/6', 'maj'),
#  ('maj/7', 'maj'),
#  ('maj/b2', 'maj'),
#  ('maj/b3', 'maj'),
#  ('maj/b4', 'maj'),
#  ('maj/b5', 'maj'),
#  ('maj/b6', 'maj'),
#  ('maj/b7', 'maj'),
#  ('maj/bb6', 'maj'),
#  ('maj13', 'maj'),
#  ('maj6', 'maj'),
#  ('maj6(7)', 'maj'),
#  ('maj6(7,#11)', 'maj'),
#  ('maj6(9)', 'maj'),
#  ('maj6(9)/3', 'maj'),
#  ('maj6(9)/5', 'maj'),
#  ('maj6(b7)', 'maj'),
#  ('maj6(b7,11)', 'maj'),
#  ('maj6(b9)', 'maj'),
#  ('maj6/2', 'maj'),
#  ('maj6/3', 'maj'),
#  ('maj6/4', 'maj'),
#  ('maj6/5', 'maj'),
#  ('maj6/6', 'maj'),
#  ('maj6/b5', 'maj'),
#  ('maj6/b7', 'maj'),
#  ('maj7', 'maj'),
#  ('maj7(#11)', 'maj'),
#  ('maj7(#11)/3', 'maj'),
#  ('maj7(#5)', 'maj'),
#  ('maj7(#9)', 'maj'),
#  ('maj7(b7)/3', 'maj'),
#  ('maj7/2', 'maj'),
#  ('maj7/3', 'maj'),
#  ('maj7/4', 'maj'),
#  ('maj7/5', 'maj'),
#  ('maj7/7', 'maj'),
#  ('maj9', 'maj'),
#  ('maj9(#11)', 'maj'),
#  ('maj9(13)', 'maj'),
#  ('maj9(13,#11)', 'maj'),
#  ('maj9/3', 'maj'),
#  ('maj9/4', 'maj'),
#  ('min', 'min'),
#  ('min(11)', 'min'),
#  ('min(11)/4', 'min'),
#  ('min(11)/7', 'min'),
#  ('min(11)/b7', 'min'),
#  ('min(11,9)', 'min'),
#  ('min(9)', 'min'),
#  ('min(9)/5', 'min'),
#  ('min(9)/6', 'min'),
#  ('min(9)/7', 'min'),
#  ('min(9)/b7', 'min'),
#  ('min(b13)', 'min'),
#  ('min/2', 'min'),
#  ('min/3', 'min'),
#  ('min/4', 'min'),
#  ('min/5', 'min'),
#  ('min/6', 'min'),
#  ('min/7', 'min'),
#  ('min/b3', 'min'),
#  ('min/b6', 'min'),
#  ('min/b7', 'min'),
#  ('min/b8', 'min'),
#  ('min/bb7', 'min'),
#  ('min11', 'min'),
#  ('min11/5', 'min'),
#  ('min11/b3', 'min'),
#  ('min11/b7', 'min'),
#  ('min13', 'min'),
#  ('min6', 'min'),
#  ('min6(#11)', 'min'),
#  ('min6(7)', 'min'),
#  ('min6(9)/5', 'min'),
#  ('min6/2', 'min'),
#  ('min6/5', 'min'),
#  ('min6/b3', 'min'),
#  ('min7', 'min'),
#  ('min7(11)', 'min'),
#  ('min7(b13)', 'min'),
#  ('min7/2', 'min'),
#  ('min7/4', 'min'),
#  ('min7/5', 'min'),
#  ('min7/6', 'min'),
#  ('min7/b2', 'min'),
#  ('min7/b3', 'min'),
#  ('min7/b7', 'min'),
#  ('min9', 'min'),
#  ('min9(b13)', 'min'),
#  ('min9/2', 'min'),
#  ('min9/4', 'min'),
#  ('min9/5', 'min'),
#  ('min9/b3', 'min'),
#  ('min9/b7', 'min'),
#  ('minmaj7', 'min'),
#  ('minmaj7/5', 'min'),
#  ('minmaj7/7', 'min'),
#  ('sus2', 'N'),
#  ('sus2(#11)', 'N'),
#  ('sus2(b7)', 'N'),
#  ('sus2/2', 'N'),
#  ('sus2/3', 'N'),
#  ('sus2/5', 'N'),
#  ('sus4', 'N'),
#  ('sus4(9)', 'N'),
#  ('sus4(9)/7', 'N'),
#  ('sus4(b13,b7)', 'N'),
#  ('sus4(b7)', 'N'),
#  ('sus4(b7)/2', 'N'),
#  ('sus4(b7)/4', 'N'),
#  ('sus4(b7)/5', 'N'),
#  ('sus4(b7)/b7', 'N'),
#  ('sus4(b7,9)', 'N'),
#  ('sus4(b7,9)/2', 'N'),
#  ('sus4(b7,9)/5', 'N'),
#  ('sus4(b7,9,#11)', 'N'),
#  ('sus4(b7,9,13)', 'N'),
#  ('sus4/2', 'N'),
#  ('sus4/4', 'N'),
#  ('sus4/5', 'N'),
#  ('sus4/7', 'N'),
#  ('sus4/b7', 'N')]

# %%
chord_types
